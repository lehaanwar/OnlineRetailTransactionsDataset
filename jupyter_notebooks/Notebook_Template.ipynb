# %% [markdown]
# # **Online Retail Transaction Dataset Project**

# %% [markdown]
# ## Objectives
#
# * The first thing required is to obtain the raw dataset from Kaggle, please see below;
# https://www.kaggle.com/datasets/abhishekrp1517/online-retail-transactions-dataset.
# The next step is to look, clean, analyse the raw data. Once we have our clean data, we then use data visualisation tools to show our analysis of the data.
#
# ## Inputs
#
# * Raw data from Kaggle
# numpy, pandas, seaborn, matplotlib, plotly.
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\leha_\\Documents\\vscode-projects\\OnlineRetailTransactionsDataset\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\leha_\\Documents\\vscode-projects\\OnlineRetailTransactionsDataset'

# %% [markdown]
# # Section 1

# %% [markdown]
# Section 1 content

# %%
# import all libraries that you need in this project
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Section 2 content

# %% [markdown]
# ---

# %%
# Load the raw dataset
df = pd.read_csv('../dataset/Rawdata/Online-Retail.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Load the raw dataset
# ----> 2 df = pd.read_csv('../dataset/Rawdata/Online-Retail.csv')
#       3 df.head()
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  int64
#  7   Country      541909 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 33.1+ MB

# %%
df.tail(10)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541899    581587     22726       ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730       ALARM CLOCK BAKELIKE IVORY         4
# 541901    581587     22367  CHILDRENS APRON SPACEBOY DESIGN         8
# 541902    581587     22629              SPACEBOY LUNCH BOX         12
# 541903    581587     23256      CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID Country
# 541899  2011-12-09 12:50:00       3.75       12680  France
# 541900  2011-12-09 12:50:00       3.75       12680  France
# ...

# %%
df.sample(10)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 277959    561201     22702             BLACK AND WHITE CAT BOWL         1
# 401731    571441    84707A  SILVER JEWELLED MIRROR TRINKET TRAY         1
# 183269    552655     22829            SWEETHEART WIRE WALL TIDY         2
# 424877    573289     20719               WOODLAND CHARLOTTE BAG        10
# 96305     544484     22666      RECIPE BOX PANTRY YELLOW DESIGN         6
# 516753    579946     84006            MAGIC TREE -PAPER FLOWERS        12
# 144812    548808    72799E     IVORY PILLAR CANDLE SILVER FLOCK         2
# 217555    555925     22697      GREEN REGENCY TEACUP AND SAUCER         2
# 112906    545901     22185           SLATE TILE NATURAL HANGING         3
# 372332    569238     21212      PACK OF 72 RETROSPOT CAKE CASES         3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 277959  2011-07-25 15:08:00       2.10       14692  United Kingdom
# ...

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
df[df.Country == 'France'].value_counts()
# Out:
# InvoiceNo  StockCode  Description                         Quantity  InvoiceDate          UnitPrice  CustomerID  Country
# 575661     22571      ROCKING HORSE RED CHRISTMAS          3        2011-11-10 14:39:00  0.85       12617       France     2
# 569332     23206      LUNCH BAG APPLE DESIGN               1        2011-10-03 13:46:00  1.65       12637       France     2
#            21035      SET/2 RED RETROSPOT TEA TOWELS       1        2011-10-03 13:46:00  3.25       12637       France     2
#            22328      ROUND SNACK BOXES SET OF 4 FRUITS    1        2011-10-03 13:46:00  2.95       12637       France     2
# 547194     22554      PLASTERS IN TIN WOODLAND ANIMALS     1        2011-03-21 12:42:00  1.65       12637       France     2
#                                                                                                                           ..
# ...

# %%
# check for missing values
df.isnull().sum()
# there are missing values in the dataset, 1,454 missing values in the 'Descrption' column
# Out:
# InvoiceNo         0
# StockCode         0
# Description    1454
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID        0
# Country           0
# dtype: int64

# %% [markdown]
# NOTE

# %%
# check for duplicate values
df.duplicated().sum()
df[df.duplicated()]

#there are no duplicates in the dataset

# remove duplicate values if any exists
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Load the raw dataset
df = pd.read_csv('../dataset/Rawdata/Online-Retail.csv')
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...

# %%
# handle missing values
# check missing values in the 'Description' column
df_missing = df[df['Description'].isnull()]
df_missing.head(10)
# Out:
#      InvoiceNo StockCode Description  Quantity          InvoiceDate  \
# 622     536414     22139         NaN        56  2010-12-01 11:52:00
# 1970    536545     21134         NaN         1  2010-12-01 14:32:00
# 1971    536546     22145         NaN         1  2010-12-01 14:33:00
# 1972    536547     37509         NaN         1  2010-12-01 14:33:00
# 1987    536549    85226A         NaN         1  2010-12-01 14:34:00
# 1988    536550     85044         NaN         1  2010-12-01 14:34:00
# 2024    536552     20950         NaN         1  2010-12-01 14:34:00
# 2025    536553     37461         NaN         3  2010-12-01 14:35:00
# 2026    536554     84670         NaN        23  2010-12-01 14:35:00
# 2406    536589     21777         NaN       -10  2010-12-01 16:50:00
#
#       UnitPrice  CustomerID         Country
# 622         0.0       15287  United Kingdom
# 1970        0.0       15287  United Kingdom
# 1971        0.0       15287  United Kingdom
# ...

# %%
# check if missing values correlate with 'country' column
df_missing['Country'].value_counts()
# all the missing values are from 'United Kingdom' - these could be due to data entry errors in the UK warehouse or a system glitch affecting only UK entries. Further investigation is needed to determine the exact cause.
# Out:
# Country
# United Kingdom    1454
# Name: count, dtype: int64

# %%
#Remove rows with missing values in the 'Description' column
df = df.dropna(subset=['Description'])

# Check again for missing values
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
#visual representation of missing values
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
# save the cleaned dataset
df.to_csv('Cleandataset.csv', index=False)

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %%
import pandas as pd

#load cleaned dataset
df_cleaned = pd.read_csv('../dataset/Cleandataset/Cleandataset.csv')
print(f"✅ Loaded cleaned data: {df_cleaned.shape[0]:,} rows × {df_cleaned.shape[1]} columns")

# Quick preview
df_cleaned.head()
# Out:
# ✅ Loaded cleaned data: 540,455 rows × 8 columns
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010-12-01 08:26:00       3.39       17850  United Kingdom

# %%
#check for outliers
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_cleaned, x='Quantity')
plt.title('Boxplot of Quantity')
plt.show()

# %%
# show outliers in 'Quantity' column
df_cleaned['Quantity'].describe()
# Out:
# count    540455.000000
# mean          9.603129
# std         218.007598
# min      -80995.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
#Remove retail transactions with negative 'Quantity' values
df_cleaned = df_cleaned[df_cleaned['Quantity'] >= 0]
#Check the statistics again
df_cleaned['Quantity'].describe()
# Out:
# count    530693.000000
# mean         10.605819
# std         156.637853
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
#As there is a high maximum value in 'Quantity' column, we will further investigate transactions with Quantity greater than 1000
df_high_quantity = df_cleaned[df_cleaned['Quantity'] > 1000]
df_high_quantity
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 4838      536809     84950     ASSORTED COLOUR T-LIGHT HOLDER      1824
# 4933      536830     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 4934      536830     21915             RED  HARMONICA IN BOX       1400
# 6353      536890    17084R              ASSORTED INCENSE PACK      1440
# 16375     537659     22189            CREAM HEART CARD HOLDER      1008
# ...          ...       ...                                ...       ...
# 532363    581115     22413    METAL SIGN TAKE IT OR LEAVE IT       1404
# 533503    581175     23084                 RABBIT NIGHT LIGHT      1440
# 538616    581458     22197                     POPCORN HOLDER      1500
# 538617    581459     22197                     POPCORN HOLDER      1200
# 538967    581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#Remove high outliers in 'Quantity' column by setting a threshold of 1000
df_cleaned = df_cleaned[df_cleaned['Quantity'] <= 1000]
#Check the statistics again
df_cleaned['Quantity'].describe()
# Out:
# count    530580.000000
# mean          9.940426
# std          28.337466
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max        1000.000000
# Name: Quantity, dtype: float64

# %% [markdown]
# ---

# %%
# show outliers in 'UnitPrice' column
df_cleaned['UnitPrice'].describe()
# Out:
# count    530580.000000
# mean          3.862229
# std          41.837592
# min      -11062.060000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       13541.330000
# Name: UnitPrice, dtype: float64

# %%
#Remove outliers in negative 'UnitPrice' values
df_cleaned = df_cleaned[df_cleaned['UnitPrice'] >= 0]   
#check the statistics again
df_cleaned['UnitPrice'].describe()
# Out:
# count    530578.000000
# mean          3.903942
# std          35.899840
# min           0.000000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       13541.330000
# Name: UnitPrice, dtype: float64

# %%
# Remove outliers in high 'UnitPrice' values by setting a threshold of 100
df_cleaned = df_cleaned[df_cleaned['UnitPrice'] <= 100]
#check the statistics again
df_cleaned['UnitPrice'].describe()
# Out:
# count    529767.000000
# mean          3.289161
# std           3.804854
# min           0.000000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max         100.000000
# Name: UnitPrice, dtype: float64

# %%
#check the structure of the dataset
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 529767 entries, 0 to 540454
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    529767 non-null  object
#  1   StockCode    529767 non-null  object
#  2   Description  529767 non-null  object
#  3   Quantity     529767 non-null  int64
#  4   InvoiceDate  529767 non-null  object
#  5   UnitPrice    529767 non-null  float64
#  6   CustomerID   529767 non-null  int64
#  7   Country      529767 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 36.4+ MB

# %%
#update the cleaned dataset after outlier removal
df_cleaned.to_csv('../dataset/Cleandataset/Cleandataset.csv', index=False)

#check the first few rows of the updated cleaned dataset
df_cleaned.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010-12-01 08:26:00       3.39       17850  United Kingdom

# %%
#load the cleaned dataset
df_cleaned = pd.read_csv('../dataset/Cleandataset/Cleandataset.csv')
print(f"✅ Loaded cleaned data: {df_cleaned.shape[0]:,} rows × {df_cleaned.shape[1]} columns")
# Out:
# ✅ Loaded cleaned data: 529,767 rows × 8 columns

# %%
# Check the mean vs median of 'UnitPrice' to confirm normal distribution
df_cleaned['UnitPrice'].mean(), df_cleaned['UnitPrice'].median()
df_cleaned['UnitPrice'].hist(bins=50)
plt.title('Distribution of UnitPrice')
plt.show()

# %%
# Check mean vs median against first hypothesis seasonal products have higher unit prices due to demand spikes during specific times of the year.
df.groupby('InvoiceDate')['UnitPrice'].mean().sort_values(ascending=False).head(10)
# Out:
# InvoiceDate
# 2011-06-10 15:31:00    38970.00
# 2011-12-05 11:36:00    17836.46
# 2011-01-05 09:55:00    16888.02
# 2011-01-05 09:57:00    16453.71
# 2010-12-07 15:08:00    13541.33
# 2010-12-07 15:49:00    13541.33
# 2011-12-05 11:35:00    11586.50
# 2011-11-07 15:21:00     8286.22
# 2011-05-03 13:46:00     8142.75
# 2011-05-03 12:51:00     8142.75
# Name: UnitPrice, dtype: float64

# %%
#Create a new column 'TotalTransactionValue' as Quantity * UnitPrice
df['TotalTransactionValue'] = df['Quantity'] * df['UnitPrice']  
print(df.head())
df[['Description', 'Quantity', 'UnitPrice', 'TotalTransactionValue']]
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010-12-01 08:26:00       3.39       17850  United Kingdom
#
#    TotalTransactionValue
# 0                  15.30
# 1                  20.34
# 2                  22.00
# 3                  20.34
# 4                  20.34
# ...

# %%
#Data visualization example 
import matplotlib.pyplot as plt
import seaborn as sns

#show the boxplot of 'TotalTransactionValue'
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_cleaned[df_cleaned['TotalTransactionValue'] > 0], x='TotalTransactionValue')
plt.title('Boxplot of TotalTransactionValue')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#load the cleaned dataset
df_cleaned = pd.read_csv('../dataset/Cleandataset/Cleandataset.csv')
print(f"✅ Loaded cleaned data: {df_cleaned.shape[0]:,} rows × {df_cleaned.shape[1]} columns")
df_cleaned.head()
# Out:
# ✅ Loaded cleaned data: 529,767 rows × 8 columns
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010-12-01 08:26:00       3.39       17850  United Kingdom

# %%
if 'TotalTransactionValue' not in df_cleaned.columns:
    df_cleaned['TotalTransactionValue'] = df_cleaned['Quantity'] * df_cleaned['UnitPrice']
df_cleaned.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010-12-01 08:26:00       3.39       17850  United Kingdom
#
#    TotalTransactionValue
# 0                  15.30
# 1                  20.34
# 2                  22.00
# 3                  20.34
# 4                  20.34

# %%
#Show heatmap of total transaction values by country as shown up 2nd hypothesis, certain countries have higher total transaction values due to larger customer bases or higher purchasing power.
plt.figure(figsize=(12, 8))
country_totals = df_cleaned.groupby('Country')['TotalTransactionValue'].sum().reset_index()
country_pivot = country_totals.pivot_table(values='TotalTransactionValue', index='Country')
sns.heatmap(country_pivot, annot=True, fmt=".0f", cmap='YlGnBu')
plt.title('Total Transaction Values by Country')
plt.show()

# %%
# show histogram of total transaction values by country 
plt.figure(figsize=(12, 8))
country_totals = df_cleaned.groupby('Country')['TotalTransactionValue'].sum().reset_index()
sns.barplot(data=country_totals, x='Country', y='TotalTransactionValue')
plt.title('Total Transaction Values by Country')
plt.show()

# %%
#show scatter plot of Quantity vs UnitPrice to see if there's any correlation as shown in 3rd hypothesis, lower priced products may encourage higher quantities purchased.
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_cleaned, x='UnitPrice', y='Quantity')
plt.title('Scatter Plot of Quantity vs UnitPrice')
plt.show()

# %%
#show bar chart of total transaction values by country
plt.figure(figsize=(12, 8))
sns.barplot(data=country_totals, x='Country', y='TotalTransactionValue')
plt.title('Total Transaction Values by Country')
plt.show()

# %%
#show scatter plot of Seasonal products have higher unit prices due to demand spikes during specific times of the year
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_cleaned, x='InvoiceDate', y='UnitPrice')
plt.title('Scatter Plot of UnitPrice over Time')
plt.show()

# %% [markdown]
# ## Conclusion and Next Steps
